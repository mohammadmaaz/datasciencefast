# %%
import numpy as np

# %%
from sklearn.decomposition import PCA

# %%
X = np.array([[1.31, 1.89], [2.31, 2.32], [3.12, 3.92], [3.91, 6.31], [2.71, 1.87], [2.28, 3.37],[2.91, 8.65]])

# %%
pca = PCA(n_components=2)

# %%
pca.fit(X)
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-039834194559> in <module>()
#       1 PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
# ----> 2   svd_solver='auto', tol=0.0, whiten=False)
#
# TypeError: __init__() got an unexpected keyword argument 'svd_solver'

# %%
PCA(copy=True, n_components=2, whiten=False)
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [ 0.94513714  0.05486286]

# %%
X
# Out:
# array([[ 1.31,  1.89],
#        [ 2.31,  2.32],
#        [ 3.12,  3.92],
#        [ 3.91,  6.31],
#        [ 2.71,  1.87],
#        [ 2.28,  3.37],
#        [ 2.91,  8.65]])

# %%
print(__doc__)

import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

iris = datasets.load_iris()

X = iris.data
y = iris.target
target_names = iris.target_names

pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

lda = LinearDiscriminantAnalysis(n_components=2)
X_r2 = lda.fit(X, y).transform(X)

# Percentage of variance explained for each components
print('explained variance ratio (first two components): %s'
      % str(pca.explained_variance_ratio_))

plt.figure()
colors = ['navy', 'turquoise', 'darkorange']
lw = 2

for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r[y == i, 0], X_r[y == i, 1], color=color, alpha=.8, lw=lw,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('PCA of IRIS dataset')

plt.figure()
for color, i, target_name in zip(colors, [0, 1, 2], target_names):
    plt.scatter(X_r2[y == i, 0], X_r2[y == i, 1], alpha=.8, color=color,
                label=target_name)
plt.legend(loc='best', shadow=False, scatterpoints=1)
plt.title('LDA of IRIS dataset')

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# explained variance ratio (first two components): [ 0.92461621  0.05301557]

# %%
colors = ['navy', 'turquoise', 'darkorange']

# %%
names = ['maaz','shumail']

# %%
zip(colors,names)

# %%
print(zip(colors,names))
# Out:
# <zip object at 0x7f3f3ba30648>

# %%
for color, name in zip(colors,names):
    print(color)
    print(name)
# Out:
# navy
# maaz
# turquoise
# shumail
