# %%
print('Hello Stocks')
# Out:
# Hello Stocks

# %%
import os
cwd = os.getcwd()

# %%
cwd
# Out:
# '/home/muhammad/Local/MS Data Science/GIT/datasciencefast'

# %%
import pandas as pd

# %%
pathbook = cwd + ('/Book2.xls')

# %%
df = pd.read_excel(pathbook,sheetname=0)

# %%
df.shape
# Out:
# (81, 9)

# %%
df.head()
# Out:
#    Unnamed: 0      Date Year ended /Half Year ended Dividend / Bonus / Right  \
# 0         NaN  20171020            30/09/2017(IIIQ)                        -
# 1         NaN  20171020            30/09/2017(IIIQ)                        -
# 2         NaN  20170811             30/06/2017(HYR)                  35% (D)
# 3         NaN  20170811             30/06/2017(HYR)                        -
# 4         NaN  20170420              31/03/2017(IQ)                  35% (D)
#
#   Profit / (Loss) Before Taxation (Rs. In Million)  \
# 0                                 16,335.610 (UCS)
# 1                                  18,757.301 (CS)
# 2                                 26,081.482 (UCS)
# 3                                  27,717.176 (CS)
# 4                                 12,512.363 (UCS)
#
#   Profit / (Loss) After Taxation (Rs. In Million) EPS (Rs.)  \
# 0                                   207.748 (UCS)      0.14
# 1                                  1,554.428 (CS)      0.87
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Year ended /Half Year ended',
#        'Dividend / Bonus / Right',
#        'Profit / (Loss) Before Taxation (Rs. In Million)',
#        'Profit / (Loss) After Taxation (Rs. In Million)', 'EPS (Rs.)',
#        'Annual General Meeting / E.O.G.M.', 'Closure Of Share Transfer Books'],
#       dtype='object')

# %%
del df['Unnamed: 0']

# %%
df.head(2)
# Out:
#        Date Year ended /Half Year ended Dividend / Bonus / Right  \
# 0  20171020            30/09/2017(IIIQ)                        -
# 1  20171020            30/09/2017(IIIQ)                        -
#
#   Profit / (Loss) Before Taxation (Rs. In Million)  \
# 0                                 16,335.610 (UCS)
# 1                                  18,757.301 (CS)
#
#   Profit / (Loss) After Taxation (Rs. In Million) EPS (Rs.)  \
# 0                                   207.748 (UCS)      0.14
# 1                                  1,554.428 (CS)      0.87
#
#   Annual General Meeting / E.O.G.M. Closure Of Share Transfer Books
# 0                                 -                               -
# 1                                 -                               -

# %%
df.tail(2)
# Out:
#         Date Year ended /Half Year ended Dividend / Bonus / Right  \
# 79  20080214              31/12/2OO7(YR)                        -
# 80  20071017            30/09/2OO7(IIIQ)                        -
#
#    Profit / (Loss) Before Taxation (Rs. In Million)  \
# 79                                            13127
# 80     16,103.208 (CD) (CS) - 14,858.968 (CD) (UCS)
#
#      Profit / (Loss) After Taxation (Rs. In Million)      EPS (Rs.)  \
# 79                                         8.041.416          11.65
# 80  10,166.197 (CD) (CS) - 9.212.560 (CD) (CS) (UCS)  13.35 - 14.64
#
#    Annual General Meeting / E.O.G.M. Closure Of Share Transfer Books
# 79                                 -                               -
# 80                                 -                               -

# %%
df['Date'] = df['Date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d'))

# %%
df
# Out:
#          Date Year ended /Half Year ended Dividend / Bonus / Right  \
# 0  2017-10-20            30/09/2017(IIIQ)                        -
# 1  2017-10-20            30/09/2017(IIIQ)                        -
# 2  2017-08-11             30/06/2017(HYR)                  35% (D)
# 3  2017-08-11             30/06/2017(HYR)                        -
# 4  2017-04-20              31/03/2017(IQ)                  35% (D)
# 5  2017-04-20              31/03/2017(IQ)                        -
# 6  2017-02-14              31/12/2016(YR)              35% (F) (D)
# 7  2017-02-14              31/12/2016(YR)                        -
# 8  2016-10-20            30/09/2016(IIIQ)                  35% (D)
# 9  2016-10-20            30/09/2016(IIIQ)                        -
# 10 2016-08-18             30/06/2016(HYR)             35% (ii) (D)
# 11 2016-08-18             30/06/2016(HYR)                        -
# 12 2016-04-22              31/03/2016(IQ)                  35% (D)
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Year ended /Half Year ended', 'Dividend / Bonus / Right',
#        'Profit / (Loss) Before Taxation (Rs. In Million)',
#        'Profit / (Loss) After Taxation (Rs. In Million)', 'EPS (Rs.)',
#        'Annual General Meeting / E.O.G.M.', 'Closure Of Share Transfer Books',
#        'DateTime'],
#       dtype='object')

# %%
s = df['Dividend / Bonus / Right'].apply(lambda x: x.split('-'))

# %%
# Out:
# 0                        [, ]
# 1                        [, ]
# 2                   [35% (D)]
# 3                        [, ]
# 4                   [35% (D)]
# 5                        [, ]
# 6               [35% (F) (D)]
# 7                        [, ]
# 8                   [35% (D)]
# 9                        [, ]
# 10             [35% (ii) (D)]
# 11                       [, ]
# 12                  [35% (D)]
# 13                       [, ]
# 14                  [35% (D)]
# 15                       [, ]
# 16              [35%(II) (D)]
# 17                       [, ]
# 18              [35%(II) (D)]
# 19                       [, ]
# 20               [35%(I) (D)]
# 21                       [, ]
# 22                  [55% (D)]
# 23                       [, ]
# 24           [22.5%(III) (D)]
# 25                       [, ]
# 26            [22.5%(II) (D)]
# 27                       [, ]
# 28                  [20% (D)]
# 29                       [, ]
#                ...
# ...

# %%
s[1]
# Out:
# ['', '']
